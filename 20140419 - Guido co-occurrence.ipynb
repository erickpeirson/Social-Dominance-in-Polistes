# %%
import tethne.readers as rd
import tethne.writers as wr
import tethne.analyze as az
from tethne.data import DataCollection, GraphCollection
import networkx as nx
import os
from collections import Counter
import matplotlib.pyplot as plt

# %%
unigrams = {}
bigrams = {}
trigrams = {}
datapath = "/Users/erickpeirson/Dropbox/Digital Hps/Files/data"
for directory in os.listdir(datapath):
    unigrams.update(rd.dfr.ngrams(datapath + "/" + directory, 'uni'))
    bigrams.update(rd.dfr.ngrams(datapath + "/" + directory, 'bi'))
    trigrams.update(rd.dfr.ngrams(datapath + "/" + directory, 'tri'))

# %%
papers = rd.dfr.from_dir(datapath)

# %%
explananda = [  ('polygyny',), 
                ('division of labor',), 
                ('hierarchy','hierarchies','hierarchical'),                               
                ('social dominance',),
                ('dominance',)]

# %%
explanantes = [ ('ovaries', 'ovary'), 
                ('relatedness',), 
                ('hormones', 'hormone', 'hormonal'), 
                ('endocrine',), 
                ('fitness',), 
                ('cost','costs',), 
                ('benefit', 'benefits'),
                ('ontogeny', 'ontogenesis', 'ontogenetic', 'developmental' ) ]

# %%
explananda
# Out:
# [('polygyny',),
#  ('division of labor',),
#  ('hierarchy', 'hierarchies', 'hierarchical'),
#  ('social dominance',),
#  ('dominance',)]

# %%
e_index = {}
for ex in explananda:
    e_index[ex[0]] = 'explananda'    
for es in explanantes:
    e_index[es[0]] = 'explanantes'

# %%
e_index
# Out:
# {'benefit': 'explanantes',
#  'cost': 'explanantes',
#  'division of labor': 'explananda',
#  'dominance': 'explananda',
#  'endocrine': 'explanantes',
#  'fitness': 'explanantes',
#  'hierarchy': 'explananda',
#  'hormones': 'explanantes',
#  'ontogeny': 'explanantes',
#  'ovaries': 'explanantes',
#  'polygyny': 'explananda',
#  'relatedness': 'explanantes',
#  'social dominance': 'explananda'}

# %%
print len(papers), len(unigrams), len(bigrams), len(trigrams)
# Out:
# 1684 1684 1684 1684

# %%
D = DataCollection(papers, index_by='doi')

# %%
D.slice('date', method='time_window', window_size=4, step_size=1)

# %%
types = {1: {d:{k:v for k,v in vals} for d,vals in unigrams.iteritems()},
         2: {d:{k:v for k,v in vals} for d,vals in bigrams.iteritems()},
         3: {d:{k:v for k,v in vals} for d,vals in trigrams.iteritems()}}

# %%
results = GraphCollection()

# %%
plt.figure(figsize=(10,5))
plt.hist([len(v) for v in unigrams.values()], bins=60, label='unigrams')
plt.hist([len(v) for v in bigrams.values()], bins=60, label='bigrams')
plt.hist([len(v) for v in trigrams.values()], bins=60, label='trigrams')
plt.legend()
plt.show()

# %%
termcounts = { ex[0]:Counter() for ex in explananda+explanantes }

# %%
for period,dois in D.axes['date'].iteritems():
    results.graphs[period] = nx.Graph()
    pairs = {}
    nodes = Counter()
    for doi in dois:
        these_ex = []
        these_es = []
        for explanandum in explananda:
            ex_found = False
            for ex_variant in explanandum:
                ex_type = len(ex_variant.split())
                try:
                    if ex_variant in types[ex_type][doi]:
                        if not ex_found:
                            nodes[explanandum[0]] += 1  
                            these_ex.append(explanandum[0])    
                            termcounts[explanandum[0]][period] += 1 
                            ex_found = True
                except:
                    pass
                
        for explanans in explanantes:
            es_found = False
            for es_variant in explanans:
                es_type = len(es_variant.split())
                try:                
                    if es_variant in types[es_type][doi]:
                        if not es_found:
                            nodes[explanans[0]] += 1  
                            these_es.append(explanans[0])    
                            termcounts[explanans[0]][period] += 1       
                            es_found = True
                except:
                    pass                    
        for ex in these_ex:
            for es in these_es:
                e_f = (ex, es)
                e_b = (es, ex)
                if e_f in pairs.keys():
                    pairs[e_f] += 1
                elif e_b in pairs.keys():
                    pairs[e_b] += 1
                else:
                    pairs[e_f] = 1                

    for pair,count in pairs.iteritems():
        for n,v in nodes.iteritems():
            results.graphs[period].add_node(n, count=v)
        results.graphs[period].add_edge(pair[0], pair[1], weight=count)
        nx.set_node_attributes(results.graphs[period], 'type', {k:v for k,v in e_index.iteritems() if k in nodes.keys()})

# %%
explananda
# Out:
# [('polygyny',),
#  ('division of labor',),
#  ('hierarchy', 'hierarchies', 'hierarchical'),
#  ('social dominance',),
#  ('dominance',)]

# %%
fig, ax1 = subplots(figsize=(10,5))

N = np.array([ len(v) for v in D.axes['date'].values() ])
ax1.bar(np.array([ d for d in D.axes['date'].keys() ])-0.5 , N, alpha=0.3, color='g')
ax2 = ax1.twinx()

skeys = sorted(termcounts[explananda[4][0]])
N_ = np.array([ float(len(D.axes['date'][d])) for d in skeys ])
C = np.array([termcounts[explananda[4][0]][k] for k in skeys])
ax2.plot(skeys, C/N_, label=explananda[4], lw=2)

ax2.legend(loc=2)
plt.xlim(1900, 2011)
plt.show()

# %%
import matplotlib.cm as cm
c = cm.get_cmap(name='Set1')

# %% [markdown]
# ##  (Normed) term frequency

# %%
tf = {}

# %%
fig, ax1 = subplots(figsize=(15,10))

N = np.array([ len(v) for v in D.axes['date'].values() ])
ax1.bar(np.array([ d for d in D.axes['date'].keys() ])-0.5 , N, alpha=0.3, color='g')
ax2 = ax1.twinx()
t = 0
for explanans in explanantes:
    skeys = sorted(termcounts[explanans[0]])
    C = np.array([termcounts[explanans[0]][k] for k in skeys])
    N_ = np.array([ float(len(D.axes['date'][d])) for d in skeys ])
    ax2.plot(skeys, C/N_, label=explanans[0], lw=3, color=c(t))
    t += 20
    tf[explanans[0]] = { skeys[i]:C[i]/N_[i] for i in xrange(len(skeys)) }
for explanandum in explananda:
    skeys = sorted(termcounts[explanandum[0]])
    C = np.array([termcounts[explanandum[0]][k] for k in skeys])
    N_ = np.array([ float(len(D.axes['date'][d])) for d in skeys ])    
    ax2.plot(skeys, C/N_, label=explanandum[0], lw=3, color=c(t))
    t += 20
    tf[explanandum[0]] = { skeys[i]:C[i]/N_[i] for i in xrange(len(skeys)) }

plt.yscale('log')
ax2.legend(loc=2)
plt.xlim(1900, 2011)
plt.show()

# %%
tf
# Out:
# {'benefit': {1871: 0.10000000000000001,
#   1872: 0.1111111111111111,
#   1873: 0.14285714285714285,
#   1874: 0.14285714285714285,
#   1877: 0.125,
#   1878: 0.14285714285714285,
#   1879: 0.20000000000000001,
#   1880: 0.5,
#   1883: 0.20000000000000001,
#   1884: 0.25,
#   1885: 0.33333333333333331,
#   1886: 0.33333333333333331,
#   1887: 0.16666666666666666,
#   1890: 0.090909090909090912,
#   1891: 0.090909090909090912,
#   1892: 0.125,
#   1893: 0.071428571428571425,
#   1894: 0.0625,
#   1895: 0.055555555555555552,
#   1896: 0.052631578947368418,
#   1897: 0.13333333333333333,
#   1898: 0.11764705882352941,
#   1899: 0.15384615384615385,
#   1900: 0.11764705882352941,
#   1901: 0.0625,
#   1909: 0.14285714285714285,
#   1910: 0.20000000000000001,
#   1911: 0.10000000000000001,
#   1912: 0.090909090909090912,
#   1919: 0.050000000000000003,
#   1920: 0.066666666666666666,
#   1921: 0.066666666666666666,
#   1922: 0.066666666666666666,
#   1924: 0.083333333333333329,
#   1925: 0.083333333333333329,
#   1926: 0.083333333333333329,
#   1927: 0.050000000000000003,
#   1928: 0.041666666666666664,
#   1929: 0.043478260869565216,
#   1930: 0.043478260869565216,
#   1931: 0.0625,
#   1936: 0.090909090909090912,
#   1937: 0.09375,
#   1938: 0.11538461538461539,
#   1939: 0.18518518518518517,
#   1940: 0.13043478260869565,
#   1941: 0.16666666666666666,
#   1942: 0.23076923076923078,
#   1943: 0.090909090909090912,
#   1944: 0.058823529411764705,
#   1945: 0.083333333333333329,
#   1946: 0.040000000000000001,
#   1947: 0.034482758620689655,
#   1948: 0.047619047619047616,
#   1949: 0.10000000000000001,
#   1950: 0.080000000000000002,
#   1951: 0.068965517241379309,
#   1952: 0.066666666666666666,
#   1956: 0.07407407407407407,
#   1957: 0.066666666666666666,
#   1958: 0.16666666666666666,
#   1959: 0.21052631578947367,
#   1960: 0.14285714285714285,
#   1961: 0.20000000000000001,
#   1962: 0.076923076923076927,
#   1963: 0.12,
#   1964: 0.13636363636363635,
#   1965: 0.10526315789473684,
#   1966: 0.20000000000000001,
#   1967: 0.25,
#   1968: 0.25,
#   1969: 0.32500000000000001,
#   1970: 0.31707317073170732,
#   1971: 0.26415094339622641,
#   1972: 0.2857142857142857,
#   1973: 0.23809523809523808,
#   1974: 0.29310344827586204,
#   1975: 0.43283582089552236,
#   1976: 0.36046511627906974,
#   1977: 0.34343434343434343,
#   1978: 0.36752136752136755,
#   1979: 0.29914529914529914,
#   1980: 0.34351145038167941,
#   1981: 0.38461538461538464,
#   1982: 0.38135593220338981,
#   1983: 0.35833333333333334,
#   1984: 0.4144144144144144,
#   1985: 0.41605839416058393,
#   1986: 0.40298507462686567,
#   1987: 0.4236111111111111,
#   1988: 0.38513513513513514,
#   1989: 0.39130434782608697,
#   1990: 0.40366972477064222,
#   1991: 0.51886792452830188,
#   1992: 0.57281553398058249,
#   1993: 0.56302521008403361,
#   1994: 0.59230769230769231,
#   1995: 0.54054054054054057,
#   1996: 0.54729729729729726,
#   1997: 0.61111111111111116,
#   1998: 0.65806451612903227,
#   1999: 0.79259259259259263,
#   2000: 0.84353741496598644,
#   2001: 0.80368098159509205,
#   2002: 0.7751479289940828,
#   2003: 0.7441860465116279,
#   2004: 0.74096385542168675,
#   2005: 0.8141025641025641,
#   2006: 0.87671232876712324,
#   2007: 0.89610389610389607,
#   2008: 0.90384615384615385,
#   2009: 0.90196078431372551,
#   2010: 0.92307692307692313},
#  'cost': {1877: 0.25,
#   1878: 0.2857142857142857,
#   1879: 0.40000000000000002,
#   1880: 1.0,
#   1898: 0.058823529411764705,
#   1899: 0.076923076923076927,
#   1900: 0.058823529411764705,
#   1901: 0.0625,
#   1905: 0.041666666666666664,
#   1906: 0.090909090909090912,
#   1907: 0.1111111111111111,
#   1908: 0.125,
#   1909: 0.14285714285714285,
#   1913: 0.083333333333333329,
#   1914: 0.090909090909090912,
#   1915: 0.1111111111111111,
#   1916: 0.076923076923076927,
#   1919: 0.050000000000000003,
#   1920: 0.066666666666666666,
#   1921: 0.066666666666666666,
#   1922: 0.066666666666666666,
#   1924: 0.16666666666666666,
#   1925: 0.16666666666666666,
#   1926: 0.41666666666666669,
#   1927: 0.25,
#   1928: 0.20833333333333334,
#   1929: 0.21739130434782608,
#   1930: 0.086956521739130432,
#   1931: 0.125,
#   1936: 0.045454545454545456,
#   1937: 0.03125,
#   1938: 0.038461538461538464,
#   1939: 0.1111111111111111,
#   1940: 0.086956521739130432,
#   1941: 0.16666666666666666,
#   1942: 0.15384615384615385,
#   1944: 0.058823529411764705,
#   1945: 0.125,
#   1946: 0.12,
#   1947: 0.10344827586206896,
#   1948: 0.095238095238095233,
#   1956: 0.037037037037037035,
#   1957: 0.033333333333333333,
#   1958: 0.041666666666666664,
#   1959: 0.15789473684210525,
#   1960: 0.095238095238095233,
#   1961: 0.20000000000000001,
#   1962: 0.15384615384615385,
#   1963: 0.12,
#   1964: 0.13636363636363635,
#   1965: 0.052631578947368418,
#   1966: 0.13333333333333333,
#   1967: 0.125,
#   1968: 0.125,
#   1969: 0.125,
#   1970: 0.12195121951219512,
#   1971: 0.11320754716981132,
#   1972: 0.16326530612244897,
#   1973: 0.23809523809523808,
#   1974: 0.34482758620689657,
#   1975: 0.5074626865671642,
#   1976: 0.5,
#   1977: 0.49494949494949497,
#   1978: 0.51282051282051277,
#   1979: 0.41025641025641024,
#   1980: 0.4580152671755725,
#   1981: 0.53076923076923077,
#   1982: 0.48305084745762711,
#   1983: 0.5,
#   1984: 0.48648648648648651,
#   1985: 0.44525547445255476,
#   1986: 0.5074626865671642,
#   1987: 0.52083333333333337,
#   1988: 0.52027027027027029,
#   1989: 0.54782608695652169,
#   1990: 0.5321100917431193,
#   1991: 0.60377358490566035,
#   1992: 0.61165048543689315,
#   1993: 0.60504201680672265,
#   1994: 0.59230769230769231,
#   1995: 0.65540540540540537,
#   1996: 0.68918918918918914,
#   1997: 0.72916666666666663,
#   1998: 0.80645161290322576,
#   1999: 0.83703703703703702,
#   2000: 0.85034013605442171,
#   2001: 0.84662576687116564,
#   2002: 0.85798816568047342,
#   2003: 0.86046511627906974,
#   2004: 0.89156626506024095,
#   2005: 0.95512820512820518,
#   2006: 0.93150684931506844,
#   2007: 0.93506493506493504,
#   2008: 0.87820512820512819,
#   2009: 0.85620915032679734,
#   2010: 0.88888888888888884},
#  'division of labor': {1905: 0.041666666666666664,
#   1906: 0.045454545454545456,
#   1907: 0.055555555555555552,
#   1908: 0.0625,
#   1919: 0.10000000000000001,
#   1920: 0.13333333333333333,
#   1921: 0.20000000000000001,
#   1922: 0.20000000000000001,
#   1923: 0.10000000000000001,
#   1924: 0.083333333333333329,
#   1930: 0.043478260869565216,
#   1931: 0.0625,
#   1932: 0.10000000000000001,
#   1933: 0.10000000000000001,
#   1936: 0.045454545454545456,
#   1937: 0.03125,
#   1938: 0.038461538461538464,
#   1939: 0.037037037037037035,
#   1947: 0.034482758620689655,
#   1948: 0.047619047619047616,
#   1949: 0.050000000000000003,
#   1950: 0.080000000000000002,
#   1951: 0.034482758620689655,
#   1952: 0.033333333333333333,
#   1953: 0.037037037037037035,
#   1958: 0.041666666666666664,
#   1959: 0.052631578947368418,
#   1960: 0.047619047619047616,
#   1961: 0.050000000000000003,
#   1964: 0.045454545454545456,
#   1965: 0.10526315789473684,
#   1966: 0.13333333333333333,
#   1967: 0.125,
#   1968: 0.083333333333333329,
#   1969: 0.10000000000000001,
#   1970: 0.097560975609756101,
#   1971: 0.094339622641509441,
#   1972: 0.12244897959183673,
#   1973: 0.071428571428571425,
#   1974: 0.1206896551724138,
#   1975: 0.17910447761194029,
#   1976: 0.15116279069767441,
#   1977: 0.13131313131313133,
#   1978: 0.11965811965811966,
#   1979: 0.085470085470085472,
#   1980: 0.099236641221374045,
#   1981: 0.12307692307692308,
#   1982: 0.11864406779661017,
#   1983: 0.11666666666666667,
#   1984: 0.10810810810810811,
#   1985: 0.094890510948905105,
#   1986: 0.097014925373134331,
#   1987: 0.10416666666666667,
#   1988: 0.13513513513513514,
#   1989: 0.14782608695652175,
#   1990: 0.16513761467889909,
#   1991: 0.15094339622641509,
#   1992: 0.14563106796116504,
#   1993: 0.16806722689075632,
#   1994: 0.14615384615384616,
#   1995: 0.17567567567567569,
#   1996: 0.14189189189189189,
#   1997: 0.125,
#   1998: 0.13548387096774195,
#   1999: 0.12592592592592591,
#   2000: 0.14285714285714285,
#   2001: 0.1411042944785276,
#   2002: 0.1242603550295858,
#   2003: 0.11627906976744186,
#   2004: 0.1144578313253012,
#   2005: 0.12179487179487179,
#   2006: 0.15068493150684931,
#   2007: 0.18181818181818182,
#   2008: 0.1858974358974359,
#   2009: 0.18954248366013071,
#   2010: 0.18803418803418803},
#  'dominance': {1925: 0.083333333333333329,
#   1926: 0.083333333333333329,
#   1927: 0.050000000000000003,
#   1928: 0.041666666666666664,
#   1936: 0.090909090909090912,
#   1937: 0.0625,
#   1938: 0.076923076923076927,
#   1939: 0.07407407407407407,
#   1940: 0.043478260869565216,
#   1941: 0.083333333333333329,
#   1942: 0.076923076923076927,
#   1943: 0.090909090909090912,
#   1944: 0.058823529411764705,
#   1945: 0.16666666666666666,
#   1946: 0.20000000000000001,
#   1947: 0.20689655172413793,
#   1948: 0.23809523809523808,
#   1949: 0.25,
#   1950: 0.20000000000000001,
#   1951: 0.17241379310344829,
#   1952: 0.20000000000000001,
#   1953: 0.14814814814814814,
#   1954: 0.10714285714285714,
#   1955: 0.1111111111111111,
#   1956: 0.07407407407407407,
#   1957: 0.033333333333333333,
#   1958: 0.20833333333333334,
#   1959: 0.21052631578947367,
#   1960: 0.19047619047619047,
#   1961: 0.25,
#   1962: 0.11538461538461539,
#   1963: 0.20000000000000001,
#   1964: 0.27272727272727271,
#   1965: 0.31578947368421051,
#   1966: 0.40000000000000002,
#   1967: 0.25,
#   1968: 0.29166666666666669,
#   1969: 0.27500000000000002,
#   1970: 0.26829268292682928,
#   1971: 0.24528301886792453,
#   1972: 0.20408163265306123,
#   1973: 0.16666666666666666,
#   1974: 0.25862068965517243,
#   1975: 0.34328358208955223,
#   1976: 0.31395348837209303,
#   1977: 0.28282828282828282,
#   1978: 0.25641025641025639,
#   1979: 0.22222222222222221,
#   1980: 0.27480916030534353,
#   1981: 0.30769230769230771,
#   1982: 0.3135593220338983,
#   1983: 0.32500000000000001,
#   1984: 0.30630630630630629,
#   1985: 0.30656934306569344,
#   1986: 0.33582089552238809,
#   1987: 0.34027777777777779,
#   1988: 0.32432432432432434,
#   1989: 0.33043478260869563,
#   1990: 0.28440366972477066,
#   1991: 0.24528301886792453,
#   1992: 0.3300970873786408,
#   1993: 0.34453781512605042,
#   1994: 0.37692307692307692,
#   1995: 0.38513513513513514,
#   1996: 0.33108108108108109,
#   1997: 0.3611111111111111,
#   1998: 0.33548387096774196,
#   1999: 0.36296296296296299,
#   2000: 0.35374149659863946,
#   2001: 0.34355828220858897,
#   2002: 0.34911242603550297,
#   2003: 0.37209302325581395,
#   2004: 0.42168674698795183,
#   2005: 0.40384615384615385,
#   2006: 0.47945205479452052,
#   2007: 0.4935064935064935,
#   2008: 0.5,
#   2009: 0.50326797385620914,
#   2010: 0.47863247863247865},
#  'endocrine': {1919: 0.050000000000000003,
#   1920: 0.066666666666666666,
#   1921: 0.066666666666666666,
#   1922: 0.066666666666666666,
#   1936: 0.045454545454545456,
#   1937: 0.03125,
#   1938: 0.038461538461538464,
#   1939: 0.037037037037037035,
#   1945: 0.083333333333333329,
#   1946: 0.080000000000000002,
#   1947: 0.068965517241379309,
#   1948: 0.095238095238095233,
#   1950: 0.040000000000000001,
#   1951: 0.034482758620689655,
#   1952: 0.033333333333333333,
#   1953: 0.037037037037037035,
#   1962: 0.038461538461538464,
#   1963: 0.080000000000000002,
#   1964: 0.090909090909090912,
#   1965: 0.10526315789473684,
#   1966: 0.066666666666666666,
#   1968: 0.041666666666666664,
#   1969: 0.025000000000000001,
#   1970: 0.024390243902439025,
#   1971: 0.037735849056603772,
#   1972: 0.020408163265306121,
#   1973: 0.023809523809523808,
#   1974: 0.051724137931034482,
#   1975: 0.044776119402985072,
#   1976: 0.034883720930232558,
#   1977: 0.050505050505050504,
#   1978: 0.02564102564102564,
#   1979: 0.017094017094017096,
#   1980: 0.022900763358778626,
#   1981: 0.015384615384615385,
#   1982: 0.025423728813559324,
#   1983: 0.041666666666666664,
#   1984: 0.045045045045045043,
#   1985: 0.036496350364963501,
#   1986: 0.052238805970149252,
#   1987: 0.055555555555555552,
#   1988: 0.067567567567567571,
#   1989: 0.078260869565217397,
#   1990: 0.082568807339449546,
#   1991: 0.066037735849056603,
#   1992: 0.077669902912621352,
#   1993: 0.075630252100840331,
#   1994: 0.061538461538461542,
#   1995: 0.0472972972972973,
#   1996: 0.0472972972972973,
#   1997: 0.048611111111111112,
#   1998: 0.051612903225806452,
#   1999: 0.059259259259259262,
#   2000: 0.047619047619047616,
#   2001: 0.055214723926380369,
#   2002: 0.04142011834319527,
#   2003: 0.058139534883720929,
#   2004: 0.048192771084337352,
#   2005: 0.032051282051282048,
#   2006: 0.041095890410958902,
#   2007: 0.051948051948051951,
#   2008: 0.064102564102564097,
#   2009: 0.078431372549019607,
#   2010: 0.094017094017094016},
#  'fitness': {1938: 0.038461538461538464,
#   1939: 0.037037037037037035,
#   1940: 0.043478260869565216,
#   1941: 0.083333333333333329,
#   1966: 0.066666666666666666,
#   1967: 0.125,
#   1968: 0.16666666666666666,
#   1969: 0.20000000000000001,
#   1970: 0.17073170731707318,
#   1971: 0.13207547169811321,
#   1972: 0.12244897959183673,
#   1973: 0.14285714285714285,
#   1974: 0.2413793103448276,
#   1975: 0.28358208955223879,
#   1976: 0.27906976744186046,
#   1977: 0.24242424242424243,
#   1978: 0.23931623931623933,
#   1979: 0.23076923076923078,
#   1980: 0.26717557251908397,
#   1981: 0.2846153846153846,
#   1982: 0.25423728813559321,
#   1983: 0.25833333333333336,
#   1984: 0.25225225225225223,
#   1985: 0.29927007299270075,
#   1986: 0.32835820895522388,
#   1987: 0.36805555555555558,
#   1988: 0.3783783783783784,
#   1989: 0.36521739130434783,
#   1990: 0.37614678899082571,
#   1991: 0.35849056603773582,
#   1992: 0.36893203883495146,
#   1993: 0.38655462184873951,
#   1994: 0.42307692307692307,
#   1995: 0.4391891891891892,
#   1996: 0.42567567567567566,
#   1997: 0.4513888888888889,
#   1998: 0.45806451612903226,
#   1999: 0.49629629629629629,
#   2000: 0.5374149659863946,
#   2001: 0.50920245398773001,
#   2002: 0.51479289940828399,
#   2003: 0.51162790697674421,
#   2004: 0.50602409638554213,
#   2005: 0.55769230769230771,
#   2006: 0.56164383561643838,
#   2007: 0.5714285714285714,
#   2008: 0.58974358974358976,
#   2009: 0.5490196078431373,
#   2010: 0.54700854700854706},
#  'hierarchy': {1936: 0.13636363636363635,
#   1937: 0.09375,
#   1938: 0.11538461538461539,
#   1939: 0.1111111111111111,
#   1944: 0.058823529411764705,
#   1945: 0.16666666666666666,
#   1946: 0.28000000000000003,
#   1947: 0.2413793103448276,
#   1948: 0.2857142857142857,
#   1949: 0.14999999999999999,
#   1950: 0.040000000000000001,
#   1951: 0.10344827586206896,
#   1952: 0.13333333333333333,
#   1953: 0.22222222222222221,
#   1954: 0.17857142857142858,
#   1955: 0.14814814814814814,
#   1956: 0.1111111111111111,
#   1957: 0.033333333333333333,
#   1958: 0.16666666666666666,
#   1959: 0.15789473684210525,
#   1960: 0.14285714285714285,
#   1961: 0.14999999999999999,
#   1962: 0.076923076923076927,
#   1963: 0.32000000000000001,
#   1964: 0.45454545454545453,
#   1965: 0.52631578947368418,
#   1966: 0.53333333333333333,
#   1967: 0.3125,
#   1968: 0.29166666666666669,
#   1969: 0.375,
#   1970: 0.36585365853658536,
#   1971: 0.26415094339622641,
#   1972: 0.24489795918367346,
#   1973: 0.11904761904761904,
#   1974: 0.17241379310344829,
#   1975: 0.22388059701492538,
#   1976: 0.19767441860465115,
#   1977: 0.19191919191919191,
#   1978: 0.19658119658119658,
#   1979: 0.19658119658119658,
#   1980: 0.21374045801526717,
#   1981: 0.26153846153846155,
#   1982: 0.28813559322033899,
#   1983: 0.31666666666666665,
#   1984: 0.36036036036036034,
#   1985: 0.32116788321167883,
#   1986: 0.38059701492537312,
#   1987: 0.36805555555555558,
#   1988: 0.33108108108108109,
#   1989: 0.39130434782608697,
#   1990: 0.33944954128440369,
#   1991: 0.28301886792452829,
#   1992: 0.4563106796116505,
#   1993: 0.38655462184873951,
#   1994: 0.43076923076923079,
#   1995: 0.4391891891891892,
#   1996: 0.34459459459459457,
#   1997: 0.39583333333333331,
#   1998: 0.34193548387096773,
#   1999: 0.37037037037037035,
#   2000: 0.38775510204081631,
#   2001: 0.38650306748466257,
#   2002: 0.39644970414201186,
#   2003: 0.41279069767441862,
#   2004: 0.43373493975903615,
#   2005: 0.47435897435897434,
#   2006: 0.5547945205479452,
#   2007: 0.59090909090909094,
#   2008: 0.61538461538461542,
#   2009: 0.56862745098039214,
#   2010: 0.53846153846153844},
#  'hormones': {1921: 0.066666666666666666,
#   1922: 0.066666666666666666,
#   1923: 0.10000000000000001,
#   1924: 0.083333333333333329,
#   1936: 0.090909090909090912,
#   1937: 0.0625,
#   1938: 0.076923076923076927,
#   1939: 0.07407407407407407,
#   1945: 0.125,
#   1946: 0.12,
#   1947: 0.10344827586206896,
#   1948: 0.14285714285714285,
#   1950: 0.040000000000000001,
#   1951: 0.034482758620689655,
#   1952: 0.066666666666666666,
#   1953: 0.18518518518518517,
#   1954: 0.14285714285714285,
#   1955: 0.18518518518518517,
#   1956: 0.14814814814814814,
#   1957: 0.10000000000000001,
#   1958: 0.125,
#   1959: 0.10526315789473684,
#   1960: 0.095238095238095233,
#   1962: 0.15384615384615385,
#   1963: 0.32000000000000001,
#   1964: 0.36363636363636365,
#   1965: 0.42105263157894735,
#   1966: 0.26666666666666666,
#   1968: 0.125,
#   1969: 0.074999999999999997,
#   1970: 0.073170731707317069,
#   1971: 0.094339622641509441,
#   1972: 0.040816326530612242,
#   1973: 0.047619047619047616,
#   1974: 0.068965517241379309,
#   1975: 0.20895522388059701,
#   1976: 0.1744186046511628,
#   1977: 0.20202020202020202,
#   1978: 0.1623931623931624,
#   1979: 0.076923076923076927,
#   1980: 0.061068702290076333,
#   1981: 0.069230769230769235,
#   1982: 0.1271186440677966,
#   1983: 0.15833333333333333,
#   1984: 0.27027027027027029,
#   1985: 0.20437956204379562,
#   1986: 0.20895522388059701,
#   1987: 0.18055555555555555,
#   1988: 0.1554054054054054,
#   1989: 0.19130434782608696,
#   1990: 0.16513761467889909,
#   1991: 0.13207547169811321,
#   1992: 0.1941747572815534,
#   1993: 0.17647058823529413,
#   1994: 0.19230769230769232,
#   1995: 0.20270270270270271,
#   1996: 0.14189189189189189,
#   1997: 0.1388888888888889,
#   1998: 0.14193548387096774,
#   1999: 0.16296296296296298,
#   2000: 0.17687074829931973,
#   2001: 0.19018404907975461,
#   2002: 0.20710059171597633,
#   2003: 0.20348837209302326,
#   2004: 0.21686746987951808,
#   2005: 0.24358974358974358,
#   2006: 0.26027397260273971,
#   2007: 0.44155844155844154,
#   2008: 0.44230769230769229,
#   2009: 0.44444444444444442,
#   2010: 0.48717948717948717},
#  'ontogeny': {1898: 0.17647058823529413,
#   1899: 0.23076923076923078,
#   1900: 0.29411764705882354,
#   1901: 0.3125,
#   1902: 0.15384615384615385,
#   1903: 0.11764705882352941,
#   1906: 0.13636363636363635,
#   1907: 0.16666666666666666,
#   1908: 0.1875,
#   1909: 0.42857142857142855,
#   1915: 0.22222222222222221,
#   1916: 0.15384615384615385,
#   1917: 0.21428571428571427,
#   1918: 0.16666666666666666,
#   1919: 0.050000000000000003,
#   1920: 0.066666666666666666,
#   1925: 0.083333333333333329,
#   1926: 0.083333333333333329,
#   1927: 0.050000000000000003,
#   1928: 0.041666666666666664,
#   1929: 0.043478260869565216,
#   1930: 0.086956521739130432,
#   1931: 0.125,
#   1932: 0.20000000000000001,
#   1933: 0.10000000000000001,
#   1934: 0.071428571428571425,
#   1935: 0.071428571428571425,
#   1936: 0.18181818181818182,
#   1937: 0.1875,
#   1938: 0.26923076923076922,
#   1939: 0.25925925925925924,
#   1940: 0.17391304347826086,
#   1941: 0.16666666666666666,
#   1942: 0.076923076923076927,
#   1943: 0.090909090909090912,
#   1944: 0.058823529411764705,
#   1945: 0.16666666666666666,
#   1946: 0.12,
#   1947: 0.10344827586206896,
#   1948: 0.14285714285714285,
#   1949: 0.14999999999999999,
#   1950: 0.16,
#   1951: 0.13793103448275862,
#   1952: 0.13333333333333333,
#   1953: 0.1111111111111111,
#   1954: 0.10714285714285714,
#   1955: 0.14814814814814814,
#   1956: 0.14814814814814814,
#   1957: 0.066666666666666666,
#   1958: 0.125,
#   1959: 0.10526315789473684,
#   1960: 0.095238095238095233,
#   1961: 0.10000000000000001,
#   1963: 0.12,
#   1964: 0.18181818181818182,
#   1965: 0.21052631578947367,
#   1966: 0.33333333333333331,
#   1967: 0.1875,
#   1968: 0.375,
#   1969: 0.34999999999999998,
#   1970: 0.36585365853658536,
#   1971: 0.32075471698113206,
#   1972: 0.30612244897959184,
#   1973: 0.2857142857142857,
#   1974: 0.2413793103448276,
#   1975: 0.32835820895522388,
#   1976: 0.2558139534883721,
#   1977: 0.25252525252525254,
#   1978: 0.26495726495726496,
#   1979: 0.23931623931623933,
#   1980: 0.22137404580152673,
#   1981: 0.24615384615384617,
#   1982: 0.28813559322033899,
#   1983: 0.28333333333333333,
#   1984: 0.42342342342342343,
#   1985: 0.46715328467153283,
#   1986: 0.55970149253731338,
#   1987: 0.60416666666666663,
#   1988: 0.58108108108108103,
#   1989: 0.62608695652173918,
#   1990: 0.56880733944954132,
#   1991: 0.5,
#   1992: 0.57281553398058249,
#   1993: 0.50420168067226889,
#   1994: 0.49230769230769234,
#   1995: 0.48648648648648651,
#   1996: 0.39189189189189189,
#   1997: 0.375,
#   1998: 0.34838709677419355,
#   1999: 0.38518518518518519,
#   2000: 0.44217687074829931,
#   2001: 0.46012269938650308,
#   2002: 0.47928994082840237,
#   2003: 0.47674418604651164,
#   2004: 0.45783132530120479,
#   2005: 0.47435897435897434,
#   2006: 0.47945205479452052,
#   2007: 0.48051948051948051,
#   2008: 0.46794871794871795,
#   2009: 0.44444444444444442,
#   2010: 0.4358974358974359},
#  'ovaries': {1888: 0.16666666666666666,
#   1889: 0.14285714285714285,
#   1890: 0.18181818181818182,
#   1891: 0.27272727272727271,
#   1892: 0.25,
#   1893: 0.2857142857142857,
#   1894: 0.1875,
#   1895: 0.22222222222222221,
#   1896: 0.21052631578947367,
#   1897: 0.20000000000000001,
#   1898: 0.17647058823529413,
#   1899: 0.076923076923076927,
#   1900: 0.17647058823529413,
#   1901: 0.125,
#   1902: 0.15384615384615385,
#   1903: 0.17647058823529413,
#   1904: 0.26666666666666666,
#   1905: 0.16666666666666666,
#   1906: 0.22727272727272727,
#   1907: 0.22222222222222221,
#   1908: 0.0625,
#   1909: 0.14285714285714285,
#   1917: 0.2857142857142857,
#   1918: 0.22222222222222221,
#   1919: 0.25,
#   1920: 0.33333333333333331,
#   1921: 0.20000000000000001,
#   1922: 0.20000000000000001,
#   1923: 0.20000000000000001,
#   1924: 0.16666666666666666,
#   1936: 0.090909090909090912,
#   1937: 0.0625,
#   1938: 0.076923076923076927,
#   1939: 0.07407407407407407,
#   1942: 0.15384615384615385,
#   1943: 0.18181818181818182,
#   1944: 0.11764705882352941,
#   1945: 0.16666666666666666,
#   1946: 0.080000000000000002,
#   1947: 0.10344827586206896,
#   1948: 0.14285714285714285,
#   1949: 0.10000000000000001,
#   1950: 0.080000000000000002,
#   1951: 0.034482758620689655,
#   1952: 0.033333333333333333,
#   1954: 0.035714285714285712,
#   1955: 0.1111111111111111,
#   1956: 0.1111111111111111,
#   1957: 0.16666666666666666,
#   1958: 0.20833333333333334,
#   1959: 0.15789473684210525,
#   1960: 0.14285714285714285,
#   1961: 0.050000000000000003,
#   1962: 0.038461538461538464,
#   1963: 0.12,
#   1964: 0.22727272727272727,
#   1965: 0.26315789473684209,
#   1966: 0.26666666666666666,
#   1967: 0.1875,
#   1968: 0.20833333333333334,
#   1969: 0.20000000000000001,
#   1970: 0.1951219512195122,
#   1971: 0.18867924528301888,
#   1972: 0.14285714285714285,
#   1973: 0.11904761904761904,
#   1974: 0.17241379310344829,
#   1975: 0.2537313432835821,
#   1976: 0.22093023255813954,
#   1977: 0.24242424242424243,
#   1978: 0.21367521367521367,
#   1979: 0.17948717948717949,
#   1980: 0.21374045801526717,
#   1981: 0.22307692307692309,
#   1982: 0.25423728813559321,
#   1983: 0.26666666666666666,
#   1984: 0.23423423423423423,
#   1985: 0.21897810218978103,
#   1986: 0.22388059701492538,
#   1987: 0.20833333333333334,
#   1988: 0.22297297297297297,
#   1989: 0.24347826086956523,
#   1990: 0.25688073394495414,
#   1991: 0.20754716981132076,
#   1992: 0.24271844660194175,
#   1993: 0.18487394957983194,
#   1994: 0.15384615384615385,
#   1995: 0.16216216216216217,
#   1996: 0.14864864864864866,
#   1997: 0.1736111111111111,
#   1998: 0.23870967741935484,
#   1999: 0.28888888888888886,
#   2000: 0.27210884353741499,
#   2001: 0.26380368098159507,
#   2002: 0.28402366863905326,
#   2003: 0.27906976744186046,
#   2004: 0.31325301204819278,
#   2005: 0.32692307692307693,
#   2006: 0.32876712328767121,
#   2007: 0.39610389610389612,
#   2008: 0.40384615384615385,
#   2009: 0.38562091503267976,
#   2010: 0.34188034188034189},
#  'polygyny': {1919: 0.050000000000000003,
#   1920: 0.066666666666666666,
#   1921: 0.066666666666666666,
#   1922: 0.066666666666666666,
#   1968: 0.041666666666666664,
#   1969: 0.050000000000000003,
#   1970: 0.04878048780487805,
#   1971: 0.075471698113207544,
#   1972: 0.061224489795918366,
#   1973: 0.071428571428571425,
#   1974: 0.10344827586206896,
#   1975: 0.11940298507462686,
#   1976: 0.10465116279069768,
#   1977: 0.10101010101010101,
#   1978: 0.085470085470085472,
#   1979: 0.085470085470085472,
#   1980: 0.12213740458015267,
#   1981: 0.13846153846153847,
#   1982: 0.16949152542372881,
#   1983: 0.19166666666666668,
#   1984: 0.1981981981981982,
#   1985: 0.23357664233576642,
#   1986: 0.26119402985074625,
#   1987: 0.22222222222222221,
#   1988: 0.20270270270270271,
#   1989: 0.17391304347826086,
#   1990: 0.14678899082568808,
#   1991: 0.16981132075471697,
#   1992: 0.21359223300970873,
#   1993: 0.23529411764705882,
#   1994: 0.22307692307692309,
#   1995: 0.18243243243243243,
#   1996: 0.17567567567567569,
#   1997: 0.11805555555555555,
#   1998: 0.14838709677419354,
#   1999: 0.16296296296296298,
#   2000: 0.1360544217687075,
#   2001: 0.13496932515337423,
#   2002: 0.088757396449704137,
#   2003: 0.093023255813953487,
#   2004: 0.084337349397590355,
#   2005: 0.089743589743589744,
#   2006: 0.11643835616438356,
#   2007: 0.097402597402597407,
#   2008: 0.096153846153846159,
#   2009: 0.1111111111111111,
#   2010: 0.094017094017094016},
#  'relatedness': {1969: 0.025000000000000001,
#   1970: 0.024390243902439025,
#   1971: 0.037735849056603772,
#   1972: 0.081632653061224483,
#   1973: 0.11904761904761904,
#   1974: 0.17241379310344829,
#   1975: 0.20895522388059701,
#   1976: 0.1744186046511628,
#   1977: 0.16161616161616163,
#   1978: 0.17094017094017094,
#   1979: 0.19658119658119658,
#   1980: 0.27480916030534353,
#   1981: 0.33076923076923076,
#   1982: 0.3559322033898305,
#   1983: 0.35833333333333334,
#   1984: 0.31531531531531531,
#   1985: 0.30656934306569344,
#   1986: 0.32835820895522388,
#   1987: 0.30555555555555558,
#   1988: 0.31756756756756754,
#   1989: 0.30434782608695654,
#   1990: 0.28440366972477066,
#   1991: 0.32075471698113206,
#   1992: 0.3300970873786408,
#   1993: 0.33613445378151263,
#   1994: 0.36923076923076925,
#   1995: 0.35810810810810811,
#   1996: 0.33783783783783783,
#   1997: 0.3611111111111111,
#   1998: 0.34838709677419355,
#   1999: 0.34814814814814815,
#   2000: 0.37414965986394561,
#   2001: 0.36809815950920244,
#   2002: 0.36094674556213019,
#   2003: 0.37790697674418605,
#   2004: 0.37951807228915663,
#   2005: 0.37179487179487181,
#   2006: 0.36986301369863012,
#   2007: 0.30519480519480519,
#   2008: 0.27564102564102566,
#   2009: 0.24183006535947713,
#   2010: 0.21367521367521367},
#  'social dominance': {1946: 0.040000000000000001,
#   1947: 0.034482758620689655,
#   1948: 0.047619047619047616,
#   1949: 0.050000000000000003,
#   1951: 0.034482758620689655,
#   1952: 0.033333333333333333,
#   1953: 0.037037037037037035,
#   1954: 0.035714285714285712,
#   1958: 0.041666666666666664,
#   1959: 0.052631578947368418,
#   1960: 0.047619047619047616,
#   1961: 0.050000000000000003,
#   1968: 0.041666666666666664,
#   1969: 0.025000000000000001,
#   1970: 0.024390243902439025,
#   1971: 0.018867924528301886,
#   1975: 0.029850746268656716,
#   1976: 0.023255813953488372,
#   1977: 0.020202020202020204,
#   1978: 0.02564102564102564,
#   1979: 0.017094017094017096,
#   1980: 0.015267175572519083,
#   1981: 0.023076923076923078,
#   1982: 0.025423728813559324,
#   1983: 0.016666666666666666,
#   1984: 0.036036036036036036,
#   1985: 0.021897810218978103,
#   1986: 0.022388059701492536,
#   1987: 0.041666666666666664,
#   1988: 0.033783783783783786,
#   1989: 0.052173913043478258,
#   1990: 0.055045871559633031,
#   1991: 0.037735849056603772,
#   1992: 0.077669902912621352,
#   1993: 0.067226890756302518,
#   1994: 0.061538461538461542,
#   1995: 0.054054054054054057,
#   1996: 0.027027027027027029,
#   1997: 0.034722222222222224,
#   1998: 0.032258064516129031,
#   1999: 0.029629629629629631,
#   2000: 0.034013605442176874,
#   2001: 0.024539877300613498,
#   2002: 0.023668639053254437,
#   2003: 0.029069767441860465,
#   2004: 0.030120481927710843,
#   2005: 0.05128205128205128,
#   2006: 0.068493150684931503,
#   2007: 0.11688311688311688,
#   2008: 0.10897435897435898,
#   2009: 0.1111111111111111,
#   2010: 0.11965811965811966}}

# %%
wr.collection.to_dxgmml(results, '/Users/erickpeirson/Desktop/guido.xgmml')

# %%
N_s = len(explanantes)
N_x = len(explananda)

# %% [markdown]
# ## Normed co-occurrence

# %%
fig = figure(figsize=(30,20))

skeys = sorted(results.graphs.keys())

for i in xrange(N_x):
    for j in xrange(N_s):
        t = i*N_s + j + 1
        ax = plt.subplot(N_x, N_s, t)
        
        ex = explananda[j][0]
        es = explanantes[i][0]
        
        svalues = []
        for k in skeys:
            g = results.graphs[k]
            try:
                svalues.append(float(g[ex][es]['weight'])/len(D.axes['date'][k]))
            except KeyError:
                svalues.append(0.)
                
        
        if i == 0:
            plt.title(ex, fontdict={'size':'16'})
        
        if j == 0:
            plt.ylabel(es, fontdict={'size':'16'})
            
#        if q == 0 and w == N_s - 1:
#            plt.legend(bbox_to_anchor=(2,1))
            
        ax.plot(skeys, svalues)
        plt.ylim(0.,.4)

# %% [markdown]
# ## Normed Pointwise Mutual Information

# %%
# Fill in missing zeros.
for term, values in tf.iteritems():
    for i in xrange(1872,2011):
        if i not in values.keys():
            tf[term][i] = 0.
        #else:
        #    tf[term][i] = float(tf[term][i])/len(D.axes['date'][i])

# %%
N_x = len(explanantes)
N_s = len(explananda)
T = len(tf[b])

# %%
nPMI = np.zeros((N_x, N_s, T))

# %%
for q in xrange(N_x):
    a = explanantes[q][0]
    for w in xrange(N_s):
        b = explananda[w][0]
        
        for t in xrange(T):
            i = 1872 + t
    
            p_x = tf[a][i]
            p_y = tf[b][i]
            try:
                p_xy = float(results.graphs[i][a][b]['weight'])/len(D.axes['date'][i])
            except KeyError:
                p_xy = 0.
            if p_x != 0 and p_y != 0:
                if pmi > 1:
                    print p_x, p_y, p_xy, pmi
                pmi = (log( p_xy /( p_x * p_y ) ))/( -1 * log(p_xy) )
                if pmi > 0.:
                    nPMI[q,w,t] = pmi
# Out:
# 0.03125 0.03125 0.03125 1.0
# 0.03125 0.03125 0.03125 1.0

# %%
fig = plt.figure(figsize=(30,20))

for q in xrange(N_x):
    a = explanantes[q][0]    
    for w in xrange(N_s):
        b = explananda[w][0]
        s = w + 1 + (N_s*q)
        ax = plt.subplot(N_x, N_s, s)
        ax.plot(xrange(1872,2011), nPMI[q,w,:], lw=3, alpha=0.3, label='nPMI')
        A = np.array( [ tf[a][i] for i in xrange(1872,2011) ] )
        B = np.array( [ tf[b][i] for i in xrange(1872,2011) ],)
        ax.plot(xrange(1872,2011), A, label='f/N Explanans')
        ax.plot(xrange(1872,2011), B, label='f/N Explanandum')
        plt.ylim(-.1, 1.)
        plt.xlim(1872, 2011)
        
        if q == 0:
            plt.title(b, fontdict={'size':'16'})
        
        if w == 0:
            plt.ylabel(a, fontdict={'size':'16'})
            
        if q == 0 and w == N_s - 1:
            plt.legend(bbox_to_anchor=(1.6,1))
plt.show()

# %%
fig = plt.figure(figsize=(30,20))

for q in xrange(N_x):
    a = explanantes[q][0]    
    for w in xrange(N_s):
        b = explananda[w][0]
        s = w + 1 + (N_s*q)
        ax = plt.subplot(N_x, N_s, s)
        
        A = np.array( [ tf[a][i] for i in xrange(1872,2011) ] )
        B = np.array( [ tf[b][i] for i in xrange(1872,2011) ] )
        
        d_nPMI = []
        d_p_x = []
        d_p_y = []
        for t in xrange(3,T):
            last = np.mean(nPMI[q,w,t-3:t-1])
            d_nPMI.append( ( nPMI[q,w,t] - last ) / np.mean(nPMI[q,w,:]) )
            d_p_x.append(   A[t] - np.mean(A[t-3:t-1] ) )#/ max(A[t-1], np.mean(A)))
            d_p_y.append(   B[t] - np.mean(B[t-3:t-1] ) )#/ max(B[t-1], np.mean(B)))         
            
        ax.plot(xrange(1875,2011), nPMI[q,w,3:], alpha=0.5, label='nPMI')  
        ax.set_xlim(1875, 2011)
        ax.set_ylim(0, 1)
        
        ax2 = ax.twinx()
        
        ax2.plot(xrange(1875,2011), np.array(d_nPMI) * np.array(d_p_x), label='dnPMI*f/N Explanans', lw=2, alpha=0.5, color='g')
        ax2.plot(xrange(1875,2011), np.array(d_nPMI) * np.array(d_p_y), label='dnPMI*f/N Explanandum', lw=2,alpha=0.5, color='r')
        ax2.set_ylim(-1.5, 1.5)
        ax2.set_xlim(1875, 2011)        

        if q == 0:
            plt.title(b, fontdict={'size':'16'})
        
        if w == 0:
            ax.set_ylabel(a, fontdict={'size':'16'})
            
        if q == 0 and w == N_s - 1:
            ax.legend(bbox_to_anchor=(1.8,1))
            ax2.legend(bbox_to_anchor=(1.8,1))            
            
plt.show()
